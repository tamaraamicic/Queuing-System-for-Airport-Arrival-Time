# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
dat_F_sub = pd.read_csv("dat_F_sub.csv")

# %%
dat_F_sub
# Out:
#       Unnamed: 0 Airfield  Flight_ID  Sch_Departure  Act_Departure  \
# 0              1      AUC      18095     1851408360     1851408360
# 1              2      AUC      18096     1851408780     1851408780
# 2              3      AUC      18097     1851410760     1851410760
# 3              4      AUC      18098     1851411960     1851411960
# 4              5      AUC      18099     1851413760     1851413760
# ...          ...      ...        ...            ...            ...
# 3579        3580      AUC      21674     1861901460     1861911600
# 3580        3581      AUC      21675     1861901760     1861901760
# 3581        3582      AUC      21676     1861903260     1861903260
# 3582        3583      AUC      21677     1861905360     1861910940
# 3583        3584      AUC      21678     1861905960     1861905960
#
#       Time_of_Day Period_of_Week Day_of_Week   Month      Season  ...   max  \
# 0     2 - MORNING    1 - WEEKDAY     5 - FRI   9-Sep  3 - SUMMER  ...  10.0
# ...

# %%
pd.unique(dat_F_sub['Airfield'])
# Out:
# array(['AUC'], dtype=object)

# %%
for column in dat_F_sub:
    print(pd.unique(dat_F_sub[column]))
    print(" ")
# Out:
# [   1    2    3 ... 3582 3583 3584]
#
# ['AUC']
#
# [18095 18096 18097 ... 21676 21677 21678]
#
# [1851408360 1851408780 1851410760 ... 1861903260 1861905360 1861905960]
#
# [1851408360 1851408780 1851410760 ... 1861903260 1861910940 1861905960]
#
# ['2 - MORNING' '3 - AFTERNOON' '4 - EVENING' '1 - NIGHT']
#
# ['1 - WEEKDAY' '2 - WEEKEND']
#
# ['5 - FRI' '6 - SAT' '7 - SUN' '1 - MON' '2 - TUE' '3 - WED' '4 - THU']
#
# ['9-Sep' '10-Oct' '11-Nov' '12-Dec']
#
# ['3 - SUMMER' '4 - AUTUMN']
#
# [2028]
#
# [ 55  38  32  21  57  44  16  35  24  23  36  43  30  50  46   8   5   6
#   11  42  28  45  26   1  20  29  25  19  14  22  18  10  39  12  33  34
#   51  17  40  13  37   9   7  41   4  31  15  27  52   3  49  48   2  58
#   62  47  53  82  69  72  61  59  79  75  54  56  97  76  64  68  80 122
#  107 105 117 112 100 111  66 220  88 125 123 115 120 109 118 106  83 166
#  102 129  63  95  74  98 101 116 108  78  84  81  89  91 103  92  70 126
# ...

# %%
plt.scatter(x = dat_F_sub['N_of_Dest_City'], y = dat_F_sub['N_of_Dest_Country'])

# %%
plt.scatter(x = dat_F_sub['sum_city_mode'], y = dat_F_sub['sum_country_mode'])
